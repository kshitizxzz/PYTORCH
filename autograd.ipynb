# %%
import torch

# %%
x = torch.tensor(3.0 , requires_grad = True)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y = x**2

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
#  dy/dx = 2x
    # 2*3 = 6
    # dy/dx = 6

# %% [markdown]
# y = x**2 , z = sin(y) , dz/dx = for any  given x

# %%
x = torch.tensor(3.0 , requires_grad = True )
x
# Out:
# tensor(3., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z = torch.sin(y)
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad 
# dz/dx
# Out:
# tensor(-5.4668)

# %% [markdown]
# complete neural network basicaly 1 perceptron

# %% [markdown]
# z = wx+b     ,
# y_pred = 1/(1+e^-z)    ,
# L = -[y_target * ln(y_pred) + (1-y_target)* ln(1-y_pred)]

# %%
w = torch.tensor(3.0 , requires_grad = True)
w
# Out:
# tensor(3., requires_grad=True)

# %%
b = torch.tensor(3.0 , requires_grad = True)
b
# Out:
# tensor(3., requires_grad=True)

# %%
x = torch.tensor(3.0)
x
# Out:
# tensor(3.)

# %%
y_target = torch.tensor(3.0)
y_target
# Out:
# tensor(3.)

# %%
print(x , y_target , w , b )
# Out:
# tensor(3.) tensor(3.) tensor(3., requires_grad=True) tensor(3., requires_grad=True)

# %%
z = w*x + b
z
# Out:
# tensor(12., grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9857, grad_fn=<SigmoidBackward0>)

# %% [markdown]
# dL/dw , dL/db

# %%
loss.backwad()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2666776529.py in <cell line: 0>()
# ----> 1 loss.backwad()
#
# NameError: name 'loss' is not defined

# %%
w.grad

# %%
b.grad

# %% [markdown]
# partiall derivatives

# %%
x = torch.tensor([2.0,4.0,6.0] , requires_grad = True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(18.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# dy/dx1 , dy/dx2 . dy/dx3
# Out:
# tensor([1.3333, 2.6667, 4.0000])

# %% [markdown]
# clearing the tensor as gradient gets stored in memory

# %%
x = torch.tensor(10.0 , requires_grad = True)

# %%
y = x**2
y
# Out:
# tensor(100., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(20.)

# %%
x.grad.zero_()
# inplace operation
# Out:
# tensor(0.)

# %% [markdown]
# turning of grad

# %% [markdown]
# x.requires_grad_(False)
# detach().
# torch.no_grad()

# %%
x = torch.tensor(4.0 , requires_grad = True)

# %%
y = x**2

# %%
x.requires_grad_(False)
# Out:
# tensor(4.)

# %%
y.backward()

# %%
x.grad

# %%
x = torch.tensor(2.0 , requires_grad = True)

# %%
z = x.detach()
z
# Out:
# tensor(2.)

# %%
y = z**2
y
# Out:
# tensor(4.)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x = torch.tensor(3.0 , requires_grad = True)
x
# Out:
# tensor(3., requires_grad=True)

# %%
with torch.no_grad():
    y = x**2
    print(y)
# Out:
# tensor(9.)

# %%
y = x**2
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()
x.grad
# Out:
# tensor(12.)
